# %%
# %matplotlib inline
import numpy as np
import h5pyd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
f = h5pyd.File('/home/john/sample/craterlake.h5', 'r', endpoint="http://192.168.1.100:5102")

# %%
list(f.keys())
# Out:
# ['Data', 'Palette', 'contour colors']

# %%
dset = f['/Data']

# %%
dset.shape
# Out:
# (320, 320)

# %%
dset.chunks
# Out:
# [320, 320]

# %%
nparr = dset[...]

# %%
nparr.shape
# Out:
# (320, 320)

# %%
plt.imshow(nparr)

# %%
f.close()
